# %% [markdown]
# <a href="https://colab.research.google.com/github/mlparthtrivedi/ML/blob/master/apriory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Apriori

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Data Preprocessing
dataset = pd.read_csv('data_final.csv',error_bad_lines=False, header = None)
transactions = []
for i in range(0, 3929):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 9)])

# Training Apriori on the dataset
from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# Visualising the results
results = list(rules)
print(results)
# Out:
# [RelationRecord(items=frozenset({'6293704005653', '6293704003673'}), support=0.003054212267752609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6293704005653'}), items_add=frozenset({'6293704003673'}), confidence=0.631578947368421, lift=23.19134284308903)]), RelationRecord(items=frozenset({'6293708000593', '6293704003673'}), support=0.007635530669381522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6293704003673'}), items_add=frozenset({'6293708000593'}), confidence=0.2803738317757009, lift=7.982527427874847), OrderedStatistic(items_base=frozenset({'6293708000593'}), items_add=frozenset({'6293704003673'}), confidence=0.2173913043478261, lift=7.982527427874848)]), RelationRecord(items=frozenset({'6293704003673', '6293708001712'}), support=0.007890048358360905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6293704003673'}), items_add=frozenset({'6293708001712'}), confidence=0.2897196261682243, lift=4.553233644859812)]), RelationRecord(items=f
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...
